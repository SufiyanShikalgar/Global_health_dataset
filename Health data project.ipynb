# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Scenario 1
# ## Task-1

# %%
# 1. load the data set

country=pd.read_csv('countryData.csv')
immun=pd.read_csv('immunitizationData.csv')

# %%
# 2. exploring shape & data set

# shape
country.shape
# Out:
# (2938, 13)

# %%
immun.shape
# Out:
# (2938, 10)

# %%
# exploring data sets

country.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  Alcohol  \
# 0  Afghanistan  2015  Developing              65.0            263.0     0.01
# 1  Afghanistan  2014  Developing              59.9            271.0     0.01
# 2  Afghanistan  2013  Developing              59.9            268.0     0.01
# 3  Afghanistan  2012  Developing              59.5            272.0     0.01
# 4  Afghanistan  2011  Developing              59.2            275.0     0.01
#
#    Total expenditure         GDP  Population   thinness  1-19 years  \
# 0               8.16  584.259210  33736494.0                   17.2
# 1               8.18  612.696514    327582.0                   17.5
# 2               8.13  631.744976  31731688.0                   17.7
# 3               8.52  669.959000   3696958.0                   17.9
# 4               7.87   63.537231   2978599.0                   18.2
#
#     thinness 5-9 years  Income composition of resources  Schooling
# 0                 17.3                            0.479       10.1
# 1                 17.5                            0.476       10.0
# 2                 17.7                            0.470        9.9
# 3                 18.0                            0.463        9.8
# 4                 18.2                            0.454        9.5

# %%
immun.head()
# Out:
#        Country  Year  infant deaths  Hepatitis B  Measles    BMI   \
# 0  Afghanistan  2015             62         65.0      1154   19.1
# 1  Afghanistan  2014             64         62.0       492   18.6
# 2  Afghanistan  2013             66         64.0       430   18.1
# 3  Afghanistan  2012             69         67.0      2787   17.6
# 4  Afghanistan  2011             71         68.0      3013   17.2
#
#    under-five deaths   Polio  Diphtheria    HIV/AIDS
# 0                  83    6.0         65.0        0.1
# 1                  86   58.0         62.0        0.1
# 2                  89   62.0         64.0        0.1
# 3                  93   67.0         67.0        0.1
# 4                  97   68.0         68.0        0.1

# %%
country.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'Alcohol', 'Total expenditure', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
immun.columns
# Out:
# Index(['Country', 'Year', 'infant deaths', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Diphtheria ', ' HIV/AIDS'],
#       dtype='object')

# %%
# 3. Correct data issues if-any

# %%
# Remove leading spaces from columns names
country.columns=country.columns.str.strip()
country.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'Alcohol', 'Total expenditure', 'GDP', 'Population',
#        'thinness  1-19 years', 'thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
immun.columns=immun.columns.str.strip()
immun.columns
# Out:
# Index(['Country', 'Year', 'infant deaths', 'Hepatitis B', 'Measles', 'BMI',
#        'under-five deaths', 'Polio', 'Diphtheria', 'HIV/AIDS'],
#       dtype='object')

# %%
# 4. Check missing values in all datasets.

# %%
country.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# Alcohol                            194
# Total expenditure                  226
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
immun.isnull().sum()
# Out:
# Country                0
# Year                   0
# infant deaths          0
# Hepatitis B          553
# Measles                0
# BMI                   34
# under-five deaths      0
# Polio                 19
# Diphtheria            19
# HIV/AIDS               0
# dtype: int64

# %%
# 5. Check duplicate values in all datasets.

# %%
country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   Alcohol                          2744 non-null   float64
#  6   Total expenditure                2712 non-null   float64
#  7   GDP                              2490 non-null   float64
#  8   Population                       2286 non-null   float64
#  9   thinness  1-19 years             2904 non-null   float64
#  10  thinness 5-9 years               2904 non-null   float64
#  11  Income composition of resources  2771 non-null   float64
#  12  Schooling                        2775 non-null   float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 298.5+ KB

# %%
country.drop_duplicates()
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Alcohol  Total expenditure         GDP  Population  \
# 0        0.01               8.16  584.259210  33736494.0
# 1        0.01               8.18  612.696514    327582.0
# 2        0.01               8.13  631.744976  31731688.0
# 3        0.01               8.52  669.959000   3696958.0
# 4        0.01               7.87   63.537231   2978599.0
# ...       ...                ...         ...         ...
# 2933     4.36               7.13  454.366654  12777511.0
# 2934     4.06               6.52  453.351155  12633897.0
# 2935     4.43               6.53   57.348340    125525.0
# 2936     1.72               6.16  548.587312  12366165.0
# 2937     1.68               7.10  547.358878  12222251.0
#
#       thinness  1-19 years  thinness 5-9 years  \
# 0                     17.2                17.3
# 1                     17.5                17.5
# 2                     17.7                17.7
# 3                     17.9                18.0
# 4                     18.2                18.2
# ...                    ...                 ...
# 2933                   9.4                 9.4
# 2934                   9.8                 9.9
# 2935                   1.2                 1.3
# 2936                   1.6                 1.7
# 2937                  11.0                11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 13 columns]

# %% [markdown]
# NO duplicate values in country table

# %%
immun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            2938 non-null   object
#  1   Year               2938 non-null   int64
#  2   infant deaths      2938 non-null   int64
#  3   Hepatitis B        2385 non-null   float64
#  4   Measles            2938 non-null   int64
#  5   BMI                2904 non-null   float64
#  6   under-five deaths  2938 non-null   int64
#  7   Polio              2919 non-null   float64
#  8   Diphtheria         2919 non-null   float64
#  9   HIV/AIDS           2938 non-null   float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 229.7+ KB

# %%
immun.drop_duplicates()
# Out:
#           Country  Year  infant deaths  Hepatitis B  Measles   BMI  \
# 0     Afghanistan  2015             62         65.0     1154  19.1
# 1     Afghanistan  2014             64         62.0      492  18.6
# 2     Afghanistan  2013             66         64.0      430  18.1
# 3     Afghanistan  2012             69         67.0     2787  17.6
# 4     Afghanistan  2011             71         68.0     3013  17.2
# ...           ...   ...            ...          ...      ...   ...
# 2933     Zimbabwe  2004             27         68.0       31  27.1
# 2934     Zimbabwe  2003             26          7.0      998  26.7
# 2935     Zimbabwe  2002             25         73.0      304  26.3
# 2936     Zimbabwe  2001             25         76.0      529  25.9
# 2937     Zimbabwe  2000             24         79.0     1483  25.5
#
#       under-five deaths  Polio  Diphtheria  HIV/AIDS
# 0                    83    6.0        65.0       0.1
# 1                    86   58.0        62.0       0.1
# 2                    89   62.0        64.0       0.1
# 3                    93   67.0        67.0       0.1
# 4                    97   68.0        68.0       0.1
# ...                 ...    ...         ...       ...
# 2933                 42   67.0        65.0      33.6
# 2934                 41    7.0        68.0      36.7
# 2935                 40   73.0        71.0      39.8
# 2936                 39   76.0        75.0      42.1
# 2937                 39   78.0        78.0      43.5
#
# [2938 rows x 10 columns]

# %% [markdown]
# No duplicate values in immun column

# %%
# 6. Analyze descriptive statistics.

# %%
country.describe(include='all')
# Out:
#             Country         Year      Status  Life expectancy  \
# count          2938  2938.000000        2938      2928.000000
# unique          193          NaN           2              NaN
# top     Afghanistan          NaN  Developing              NaN
# freq             16          NaN        2426              NaN
# mean            NaN  2007.518720         NaN        69.224932
# std             NaN     4.613841         NaN         9.523867
# min             NaN  2000.000000         NaN        36.300000
# 25%             NaN  2004.000000         NaN        63.100000
# 50%             NaN  2008.000000         NaN        72.100000
# 75%             NaN  2012.000000         NaN        75.700000
# max             NaN  2015.000000         NaN        89.000000
#
#         Adult Mortality      Alcohol  Total expenditure            GDP  \
# count       2928.000000  2744.000000         2712.00000    2490.000000
# unique              NaN          NaN                NaN            NaN
# top                 NaN          NaN                NaN            NaN
# freq                NaN          NaN                NaN            NaN
# mean         164.796448     4.602861            5.93819    7483.158469
# std          124.292079     4.052413            2.49832   14270.169342
# min            1.000000     0.010000            0.37000       1.681350
# 25%           74.000000     0.877500            4.26000     463.935626
# 50%          144.000000     3.755000            5.75500    1766.947595
# 75%          228.000000     7.702500            7.49250    5910.806335
# max          723.000000    17.870000           17.60000  119172.741800
#
#           Population  thinness  1-19 years  thinness 5-9 years  \
# count   2.286000e+03           2904.000000         2904.000000
# unique           NaN                   NaN                 NaN
# top              NaN                   NaN                 NaN
# freq             NaN                   NaN                 NaN
# mean    1.275338e+07              4.839704            4.870317
# std     6.101210e+07              4.420195            4.508882
# min     3.400000e+01              0.100000            0.100000
# 25%     1.957932e+05              1.600000            1.500000
# 50%     1.386542e+06              3.300000            3.300000
# 75%     7.420359e+06              7.200000            7.200000
# max     1.293859e+09             27.700000           28.600000
#
#         Income composition of resources    Schooling
# count                       2771.000000  2775.000000
# unique                              NaN          NaN
# top                                 NaN          NaN
# freq                                NaN          NaN
# mean                           0.627551    11.992793
# std                            0.210904     3.358920
# min                            0.000000     0.000000
# 25%                            0.493000    10.100000
# 50%                            0.677000    12.300000
# 75%                            0.779000    14.300000
# max                            0.948000    20.700000

# %%
immun.describe(include='all')
# Out:
#             Country         Year  infant deaths  Hepatitis B        Measles  \
# count          2938  2938.000000    2938.000000  2385.000000    2938.000000
# unique          193          NaN            NaN          NaN            NaN
# top     Afghanistan          NaN            NaN          NaN            NaN
# freq             16          NaN            NaN          NaN            NaN
# mean            NaN  2007.518720      30.303948    80.940461    2419.592240
# std             NaN     4.613841     117.926501    25.070016   11467.272489
# min             NaN  2000.000000       0.000000     1.000000       0.000000
# 25%             NaN  2004.000000       0.000000    77.000000       0.000000
# 50%             NaN  2008.000000       3.000000    92.000000      17.000000
# 75%             NaN  2012.000000      22.000000    97.000000     360.250000
# max             NaN  2015.000000    1800.000000    99.000000  212183.000000
#
#                 BMI  under-five deaths        Polio   Diphtheria     HIV/AIDS
# count   2904.000000        2938.000000  2919.000000  2919.000000  2938.000000
# unique          NaN                NaN          NaN          NaN          NaN
# top             NaN                NaN          NaN          NaN          NaN
# freq            NaN                NaN          NaN          NaN          NaN
# mean      38.321247          42.035739    82.550188    82.324084     1.742103
# std       20.044034         160.445548    23.428046    23.716912     5.077785
# min        1.000000           0.000000     3.000000     2.000000     0.100000
# 25%       19.300000           0.000000    78.000000    78.000000     0.100000
# 50%       43.500000           4.000000    93.000000    93.000000     0.100000
# 75%       56.200000          28.000000    97.000000    97.000000     0.800000
# max       87.300000        2500.000000    99.000000    99.000000    50.600000

# %% [markdown]
# # Task 2:

# %%
# 1. Merge both the dataset with the unique key (create if not available). Also, remove duplicate columns.

# %%
# creating unique key to join both data frames

# %%
country['key']=country['Country']+'-'+country['Year'].astype(str)
country.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  Alcohol  \
# 0  Afghanistan  2015  Developing             65.0            263.0     0.01
# 1  Afghanistan  2014  Developing             59.9            271.0     0.01
# 2  Afghanistan  2013  Developing             59.9            268.0     0.01
# 3  Afghanistan  2012  Developing             59.5            272.0     0.01
# 4  Afghanistan  2011  Developing             59.2            275.0     0.01
#
#    Total expenditure         GDP  Population  thinness  1-19 years  \
# 0               8.16  584.259210  33736494.0                  17.2
# 1               8.18  612.696514    327582.0                  17.5
# 2               8.13  631.744976  31731688.0                  17.7
# 3               8.52  669.959000   3696958.0                  17.9
# 4               7.87   63.537231   2978599.0                  18.2
#
#    thinness 5-9 years  Income composition of resources  Schooling  \
# 0                17.3                            0.479       10.1
# 1                17.5                            0.476       10.0
# 2                17.7                            0.470        9.9
# 3                18.0                            0.463        9.8
# 4                18.2                            0.454        9.5
#
#                 key
# 0  Afghanistan-2015
# 1  Afghanistan-2014
# 2  Afghanistan-2013
# 3  Afghanistan-2012
# 4  Afghanistan-2011

# %%
immun['key']=immun['Country']+'-'+immun['Year'].astype(str)
immun.head()
# Out:
#        Country  Year  infant deaths  Hepatitis B  Measles   BMI  \
# 0  Afghanistan  2015             62         65.0     1154  19.1
# 1  Afghanistan  2014             64         62.0      492  18.6
# 2  Afghanistan  2013             66         64.0      430  18.1
# 3  Afghanistan  2012             69         67.0     2787  17.6
# 4  Afghanistan  2011             71         68.0     3013  17.2
#
#    under-five deaths  Polio  Diphtheria  HIV/AIDS               key
# 0                 83    6.0        65.0       0.1  Afghanistan-2015
# 1                 86   58.0        62.0       0.1  Afghanistan-2014
# 2                 89   62.0        64.0       0.1  Afghanistan-2013
# 3                 93   67.0        67.0       0.1  Afghanistan-2012
# 4                 97   68.0        68.0       0.1  Afghanistan-2011

# %%
# Merging two data frames
df1=pd.merge(country, immun, on='key')

# %%
df1.head()
# Out:
#      Country_x  Year_x      Status  Life expectancy  Adult Mortality  Alcohol  \
# 0  Afghanistan    2015  Developing             65.0            263.0     0.01
# 1  Afghanistan    2014  Developing             59.9            271.0     0.01
# 2  Afghanistan    2013  Developing             59.9            268.0     0.01
# 3  Afghanistan    2012  Developing             59.5            272.0     0.01
# 4  Afghanistan    2011  Developing             59.2            275.0     0.01
#
#    Total expenditure         GDP  Population  thinness  1-19 years  ...  \
# 0               8.16  584.259210  33736494.0                  17.2  ...
# 1               8.18  612.696514    327582.0                  17.5  ...
# 2               8.13  631.744976  31731688.0                  17.7  ...
# 3               8.52  669.959000   3696958.0                  17.9  ...
# 4               7.87   63.537231   2978599.0                  18.2  ...
#
#      Country_y  Year_y  infant deaths Hepatitis B Measles   BMI  \
# 0  Afghanistan    2015             62        65.0    1154  19.1
# 1  Afghanistan    2014             64        62.0     492  18.6
# 2  Afghanistan    2013             66        64.0     430  18.1
# 3  Afghanistan    2012             69        67.0    2787  17.6
# 4  Afghanistan    2011             71        68.0    3013  17.2
#
#    under-five deaths  Polio  Diphtheria  HIV/AIDS
# 0                 83    6.0        65.0       0.1
# 1                 86   58.0        62.0       0.1
# 2                 89   62.0        64.0       0.1
# 3                 93   67.0        67.0       0.1
# 4                 97   68.0        68.0       0.1
#
# [5 rows x 24 columns]

# %%
# checking column names, so we can remove duolicate and unnecessary columns
df1.columns
# Out:
# Index(['Country_x', 'Year_x', 'Status', 'Life expectancy', 'Adult Mortality',
#        'Alcohol', 'Total expenditure', 'GDP', 'Population',
#        'thinness  1-19 years', 'thinness 5-9 years',
#        'Income composition of resources', 'Schooling', 'key', 'Country_y',
#        'Year_y', 'infant deaths', 'Hepatitis B', 'Measles', 'BMI',
#        'under-five deaths', 'Polio', 'Diphtheria', 'HIV/AIDS'],
#       dtype='object')

# %%
# removing duplicate columns
df1.drop(['Country_y','Year_y','key'],axis=1,inplace=True)

# renaming columns COuntry and year as per origional data
df1.rename(columns={'Country_x':'Country','Year_x':'Year','Life expectancy':'Life_expectancy',
                   'Adult Mortality':'Adult_Mortality','Total expenditure':'Total_expenditure',
                   'thinness  1-19 years':'thinness_1_19_years', 'thinness 5-9 years':'thinness_5_9_years',
                   'Income composition of resources':'Income_composition_of_resources',
                   'infant deaths':'infant_deaths', 'Hepatitis B':'Hepatitis_B',
                   'under-five deaths':'under_five_deaths','HIV/AIDS':'HIV_AIDS'}, inplace=True)
df1.head()
# Out:
#        Country  Year      Status  Life_expectancy  Adult_Mortality  Alcohol  \
# 0  Afghanistan  2015  Developing             65.0            263.0     0.01
# 1  Afghanistan  2014  Developing             59.9            271.0     0.01
# 2  Afghanistan  2013  Developing             59.9            268.0     0.01
# 3  Afghanistan  2012  Developing             59.5            272.0     0.01
# 4  Afghanistan  2011  Developing             59.2            275.0     0.01
#
#    Total_expenditure         GDP  Population  thinness_1_19_years  ...  \
# 0               8.16  584.259210  33736494.0                 17.2  ...
# 1               8.18  612.696514    327582.0                 17.5  ...
# 2               8.13  631.744976  31731688.0                 17.7  ...
# 3               8.52  669.959000   3696958.0                 17.9  ...
# 4               7.87   63.537231   2978599.0                 18.2  ...
#
#    Income_composition_of_resources  Schooling  infant_deaths  Hepatitis_B  \
# 0                            0.479       10.1             62         65.0
# 1                            0.476       10.0             64         62.0
# 2                            0.470        9.9             66         64.0
# 3                            0.463        9.8             69         67.0
# 4                            0.454        9.5             71         68.0
#
#    Measles   BMI  under_five_deaths  Polio  Diphtheria  HIV_AIDS
# 0     1154  19.1                 83    6.0        65.0       0.1
# 1      492  18.6                 86   58.0        62.0       0.1
# 2      430  18.1                 89   62.0        64.0       0.1
# 3     2787  17.6                 93   67.0        67.0       0.1
# 4     3013  17.2                 97   68.0        68.0       0.1
#
# [5 rows x 21 columns]

# %%
# exploring data frame
df1.describe(include='all')
# Out:
#             Country         Year      Status  Life_expectancy  \
# count          2938  2938.000000        2938      2928.000000
# unique          193          NaN           2              NaN
# top     Afghanistan          NaN  Developing              NaN
# freq             16          NaN        2426              NaN
# mean            NaN  2007.518720         NaN        69.224932
# std             NaN     4.613841         NaN         9.523867
# min             NaN  2000.000000         NaN        36.300000
# 25%             NaN  2004.000000         NaN        63.100000
# 50%             NaN  2008.000000         NaN        72.100000
# 75%             NaN  2012.000000         NaN        75.700000
# max             NaN  2015.000000         NaN        89.000000
#
#         Adult_Mortality      Alcohol  Total_expenditure            GDP  \
# count       2928.000000  2744.000000         2712.00000    2490.000000
# unique              NaN          NaN                NaN            NaN
# top                 NaN          NaN                NaN            NaN
# freq                NaN          NaN                NaN            NaN
# mean         164.796448     4.602861            5.93819    7483.158469
# std          124.292079     4.052413            2.49832   14270.169342
# min            1.000000     0.010000            0.37000       1.681350
# 25%           74.000000     0.877500            4.26000     463.935626
# 50%          144.000000     3.755000            5.75500    1766.947595
# 75%          228.000000     7.702500            7.49250    5910.806335
# max          723.000000    17.870000           17.60000  119172.741800
#
#           Population  thinness_1_19_years  ...  \
# count   2.286000e+03          2904.000000  ...
# unique           NaN                  NaN  ...
# top              NaN                  NaN  ...
# freq             NaN                  NaN  ...
# mean    1.275338e+07             4.839704  ...
# std     6.101210e+07             4.420195  ...
# min     3.400000e+01             0.100000  ...
# 25%     1.957932e+05             1.600000  ...
# 50%     1.386542e+06             3.300000  ...
# 75%     7.420359e+06             7.200000  ...
# max     1.293859e+09            27.700000  ...
#
#         Income_composition_of_resources    Schooling  infant_deaths  \
# count                       2771.000000  2775.000000    2938.000000
# unique                              NaN          NaN            NaN
# top                                 NaN          NaN            NaN
# freq                                NaN          NaN            NaN
# mean                           0.627551    11.992793      30.303948
# std                            0.210904     3.358920     117.926501
# min                            0.000000     0.000000       0.000000
# 25%                            0.493000    10.100000       0.000000
# 50%                            0.677000    12.300000       3.000000
# 75%                            0.779000    14.300000      22.000000
# max                            0.948000    20.700000    1800.000000
#
#         Hepatitis_B        Measles          BMI  under_five_deaths  \
# count   2385.000000    2938.000000  2904.000000        2938.000000
# unique          NaN            NaN          NaN                NaN
# top             NaN            NaN          NaN                NaN
# freq            NaN            NaN          NaN                NaN
# mean      80.940461    2419.592240    38.321247          42.035739
# std       25.070016   11467.272489    20.044034         160.445548
# min        1.000000       0.000000     1.000000           0.000000
# 25%       77.000000       0.000000    19.300000           0.000000
# 50%       92.000000      17.000000    43.500000           4.000000
# 75%       97.000000     360.250000    56.200000          28.000000
# max       99.000000  212183.000000    87.300000        2500.000000
#
#               Polio   Diphtheria     HIV_AIDS
# count   2919.000000  2919.000000  2938.000000
# unique          NaN          NaN          NaN
# top             NaN          NaN          NaN
# freq            NaN          NaN          NaN
# mean      82.550188    82.324084     1.742103
# std       23.428046    23.716912     5.077785
# min        3.000000     2.000000     0.100000
# 25%       78.000000    78.000000     0.100000
# 50%       93.000000    93.000000     0.100000
# 75%       97.000000    97.000000     0.800000
# max       99.000000    99.000000    50.600000
#
# [11 rows x 21 columns]

# %%
# as per above data it is clear that there are missing values in multiple columns , so we are calculating null values
df1.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life_expectancy                     10
# Adult_Mortality                     10
# Alcohol                            194
# Total_expenditure                  226
# GDP                                448
# Population                         652
# thinness_1_19_years                 34
# thinness_5_9_years                  34
# Income_composition_of_resources    167
# Schooling                          163
# infant_deaths                        0
# Hepatitis_B                        553
# Measles                              0
# BMI                                 34
# under_five_deaths                    0
# Polio                               19
# Diphtheria                          19
# HIV_AIDS                             0
# dtype: int64

# %%
df1.shape
# Out:
# (2938, 21)

# %%
# remove duplicate entries
df1.drop_duplicates()
# Out:
#           Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Alcohol  Total_expenditure         GDP  Population  thinness_1_19_years  \
# 0        0.01               8.16  584.259210  33736494.0                 17.2
# 1        0.01               8.18  612.696514    327582.0                 17.5
# 2        0.01               8.13  631.744976  31731688.0                 17.7
# 3        0.01               8.52  669.959000   3696958.0                 17.9
# 4        0.01               7.87   63.537231   2978599.0                 18.2
# ...       ...                ...         ...         ...                  ...
# 2933     4.36               7.13  454.366654  12777511.0                  9.4
# 2934     4.06               6.52  453.351155  12633897.0                  9.8
# 2935     4.43               6.53   57.348340    125525.0                  1.2
# 2936     1.72               6.16  548.587312  12366165.0                  1.6
# 2937     1.68               7.10  547.358878  12222251.0                 11.0
#
#       ...  Income_composition_of_resources  Schooling  infant_deaths  \
# 0     ...                            0.479       10.1             62
# 1     ...                            0.476       10.0             64
# 2     ...                            0.470        9.9             66
# 3     ...                            0.463        9.8             69
# 4     ...                            0.454        9.5             71
# ...   ...                              ...        ...            ...
# 2933  ...                            0.407        9.2             27
# 2934  ...                            0.418        9.5             26
# 2935  ...                            0.427       10.0             25
# 2936  ...                            0.427        9.8             25
# 2937  ...                            0.434        9.8             24
#
#       Hepatitis_B  Measles   BMI  under_five_deaths  Polio  Diphtheria  \
# 0            65.0     1154  19.1                 83    6.0        65.0
# 1            62.0      492  18.6                 86   58.0        62.0
# 2            64.0      430  18.1                 89   62.0        64.0
# 3            67.0     2787  17.6                 93   67.0        67.0
# 4            68.0     3013  17.2                 97   68.0        68.0
# ...           ...      ...   ...                ...    ...         ...
# 2933         68.0       31  27.1                 42   67.0        65.0
# 2934          7.0      998  26.7                 41    7.0        68.0
# 2935         73.0      304  26.3                 40   73.0        71.0
# 2936         76.0      529  25.9                 39   76.0        75.0
# 2937         79.0     1483  25.5                 39   78.0        78.0
#
#       HIV_AIDS
# 0          0.1
# 1          0.1
# 2          0.1
# 3          0.1
# 4          0.1
# ...        ...
# 2933      33.6
# 2934      36.7
# 2935      39.8
# 2936      42.1
# 2937      43.5
#
# [2938 rows x 21 columns]

# %%
#NO uplicate records found un data sets

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2938 entries, 0 to 2937
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life_expectancy                  2928 non-null   float64
#  4   Adult_Mortality                  2928 non-null   float64
#  5   Alcohol                          2744 non-null   float64
#  6   Total_expenditure                2712 non-null   float64
#  7   GDP                              2490 non-null   float64
#  8   Population                       2286 non-null   float64
#  9   thinness_1_19_years              2904 non-null   float64
#  10  thinness_5_9_years               2904 non-null   float64
#  11  Income_composition_of_resources  2771 non-null   float64
#  12  Schooling                        2775 non-null   float64
#  13  infant_deaths                    2938 non-null   int64
#  14  Hepatitis_B                      2385 non-null   float64
#  15  Measles                          2938 non-null   int64
#  16  BMI                              2904 non-null   float64
#  17  under_five_deaths                2938 non-null   int64
#  18  Polio                            2919 non-null   float64
#  19  Diphtheria                       2919 non-null   float64
#  20  HIV_AIDS                         2938 non-null   float64
# dtypes: float64(15), int64(4), object(2)
# memory usage: 505.0+ KB

# %% [markdown]
# # EDA

# %%
# 2. Find the continuous and categorical variables.

# %%
categorical=df1.select_dtypes(include="O")
numerical=df1.select_dtypes(exclude="O")

# %%
categorical.describe()
# Out:
#             Country      Status
# count          2938        2938
# unique          193           2
# top     Afghanistan  Developing
# freq             16        2426

# %%
numerical.describe()
# Out:
#               Year  Life_expectancy  Adult_Mortality      Alcohol  \
# count  2938.000000      2928.000000      2928.000000  2744.000000
# mean   2007.518720        69.224932       164.796448     4.602861
# std       4.613841         9.523867       124.292079     4.052413
# min    2000.000000        36.300000         1.000000     0.010000
# 25%    2004.000000        63.100000        74.000000     0.877500
# 50%    2008.000000        72.100000       144.000000     3.755000
# 75%    2012.000000        75.700000       228.000000     7.702500
# max    2015.000000        89.000000       723.000000    17.870000
#
#        Total_expenditure            GDP    Population  thinness_1_19_years  \
# count         2712.00000    2490.000000  2.286000e+03          2904.000000
# mean             5.93819    7483.158469  1.275338e+07             4.839704
# std              2.49832   14270.169342  6.101210e+07             4.420195
# min              0.37000       1.681350  3.400000e+01             0.100000
# 25%              4.26000     463.935626  1.957932e+05             1.600000
# 50%              5.75500    1766.947595  1.386542e+06             3.300000
# 75%              7.49250    5910.806335  7.420359e+06             7.200000
# max             17.60000  119172.741800  1.293859e+09            27.700000
#
#        thinness_5_9_years  Income_composition_of_resources    Schooling  \
# count         2904.000000                      2771.000000  2775.000000
# mean             4.870317                         0.627551    11.992793
# std              4.508882                         0.210904     3.358920
# min              0.100000                         0.000000     0.000000
# 25%              1.500000                         0.493000    10.100000
# 50%              3.300000                         0.677000    12.300000
# 75%              7.200000                         0.779000    14.300000
# max             28.600000                         0.948000    20.700000
#
#        infant_deaths  Hepatitis_B        Measles          BMI  \
# count    2938.000000  2385.000000    2938.000000  2904.000000
# mean       30.303948    80.940461    2419.592240    38.321247
# std       117.926501    25.070016   11467.272489    20.044034
# min         0.000000     1.000000       0.000000     1.000000
# 25%         0.000000    77.000000       0.000000    19.300000
# 50%         3.000000    92.000000      17.000000    43.500000
# 75%        22.000000    97.000000     360.250000    56.200000
# max      1800.000000    99.000000  212183.000000    87.300000
#
#        under_five_deaths        Polio   Diphtheria     HIV_AIDS
# count        2938.000000  2919.000000  2919.000000  2938.000000
# mean           42.035739    82.550188    82.324084     1.742103
# std           160.445548    23.428046    23.716912     5.077785
# min             0.000000     3.000000     2.000000     0.100000
# 25%             0.000000    78.000000    78.000000     0.100000
# 50%             4.000000    93.000000    93.000000     0.100000
# 75%            28.000000    97.000000    97.000000     0.800000
# max          2500.000000    99.000000    99.000000    50.600000

# %%
# 3. Impute missing value.

# %%
df2=df1.fillna(df1.median())
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2938 entries, 0 to 2937
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life_expectancy                  2938 non-null   float64
#  4   Adult_Mortality                  2938 non-null   float64
#  5   Alcohol                          2938 non-null   float64
#  6   Total_expenditure                2938 non-null   float64
#  7   GDP                              2938 non-null   float64
#  8   Population                       2938 non-null   float64
#  9   thinness_1_19_years              2938 non-null   float64
#  10  thinness_5_9_years               2938 non-null   float64
#  11  Income_composition_of_resources  2938 non-null   float64
#  12  Schooling                        2938 non-null   float64
#  13  infant_deaths                    2938 non-null   int64
#  14  Hepatitis_B                      2938 non-null   float64
#  15  Measles                          2938 non-null   int64
#  16  BMI                              2938 non-null   float64
#  17  under_five_deaths                2938 non-null   int64
#  18  Polio                            2938 non-null   float64
#  19  Diphtheria                       2938 non-null   float64
#  20  HIV_AIDS                         2938 non-null   float64
# dtypes: float64(15), int64(4), object(2)
# memory usage: 505.0+ KB
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2500\3129013122.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2=df1.fillna(df1.median())

# %% [markdown]
# # Scenario 2

# %% [markdown]
# # task01

# %%
# 1. univariate analysis

# %%
#country
df2.Country.value_counts().tail(20)
# Out:
# Estonia                  16
# Ethiopia                 16
# Fiji                     16
# Greece                   16
# Finland                  16
# Gabon                    16
# Gambia                   16
# Georgia                  16
# Germany                  16
# Ghana                    16
# Tuvalu                    1
# Cook Islands              1
# Marshall Islands          1
# Monaco                    1
# Palau                     1
# Niue                      1
# San Marino                1
# Nauru                     1
# Saint Kitts and Nevis     1
# Dominica                  1
# Name: Country, dtype: int64

# %% [markdown]
# there are 10 countries who have appeared just once in this data sets.
#
#
# other 183 countries have frequency of 16 times

# %%
# Year - Univariate analysis

# %%
df2.Year.describe()
# Out:
# count    2938.000000
# mean     2007.518720
# std         4.613841
# min      2000.000000
# 25%      2004.000000
# 50%      2008.000000
# 75%      2012.000000
# max      2015.000000
# Name: Year, dtype: float64

# %%
sns.boxplot(x=df2['Year'])
plt.show()

# %%
# Status - Univariate analysis

# %%
df2.Status.value_counts()
# Out:
# Developing    2426
# Developed      512
# Name: Status, dtype: int64

# %%
# finding total no. of developed and developing countries

df3 = df2[df2['Status'].isin(['Developing'])] 
df4 = df2[df2['Status'].isin(['Developed'])] 
print('Sum of Developing countries are= ', df3.Country.value_counts().count())
print('Sum of Developed countries are= ',df4.Country.value_counts().count())
# Out:
# Sum of Developing countries are=  161
# Sum of Developed countries are=  32

# %%
# Life expectancy univariate analysis

# %%
df2.Life_expectancy.describe()
# Out:
# count    2938.000000
# mean       69.234717
# std         9.509115
# min        36.300000
# 25%        63.200000
# 50%        72.100000
# 75%        75.600000
# max        89.000000
# Name: Life_expectancy, dtype: float64

# %%
df2.Life_expectancy.value_counts().head(10)
# Out:
# 73.0    45
# 75.0    33
# 78.0    31
# 73.6    28
# 76.0    25
# 73.9    25
# 81.0    25
# 74.7    24
# 74.5    24
# 74.2    23
# Name: Life_expectancy, dtype: int64

# %%
sns.boxplot(x=df2['Life_expectancy'])
plt.show()

# %%
# Adult_Mortality - Univariate analysis

# %%
df2.Adult_Mortality.describe()
# Out:
# count    2938.000000
# mean      164.725664
# std       124.086215
# min         1.000000
# 25%        74.000000
# 50%       144.000000
# 75%       227.000000
# max       723.000000
# Name: Adult_Mortality, dtype: float64

# %%
sns.boxplot(x=df2['Adult_Mortality'])
plt.show()

# %%
# Alcohol - Univariate analysis

# %%
df2.Alcohol.describe()
# Out:
# count    2938.000000
# mean        4.546875
# std         3.921946
# min         0.010000
# 25%         1.092500
# 50%         3.755000
# 75%         7.390000
# max        17.870000
# Name: Alcohol, dtype: float64

# %%
sns.boxplot(x=df2['Alcohol'])
plt.show()

# %%
# Total_expenditure - Univariate analysis

# %%
df2.Total_expenditure.describe()
# Out:
# count    2938.000000
# mean        5.924098
# std         2.400770
# min         0.370000
# 25%         4.370000
# 50%         5.755000
# 75%         7.330000
# max        17.600000
# Name: Total_expenditure, dtype: float64

# %%
sns.boxplot(x=df2['Total_expenditure'])
plt.show()

# %%
# GDP - Univariate analysis

# %%
df2.GDP.describe()
# Out:
# count      2938.000000
# mean       6611.523863
# std       13296.603449
# min           1.681350
# 25%         580.486996
# 50%        1766.947595
# 75%        4779.405190
# max      119172.741800
# Name: GDP, dtype: float64

# %%
sns.boxplot(x=df2['GDP'])
plt.show()

# %%
# Population - Univariate analysis

# %%
df2.Population.describe()
# Out:
# count    2.938000e+03
# mean     1.023085e+07
# std      5.402242e+07
# min      3.400000e+01
# 25%      4.189172e+05
# 50%      1.386542e+06
# 75%      4.584371e+06
# max      1.293859e+09
# Name: Population, dtype: float64

# %%
sns.boxplot(x=df2['Population'])
plt.show()

# %%
# thinness_1-19_years - Univariate analysis

# %%
df2.thinness_1_19_years.describe()
# Out:
# count    2938.000000
# mean        4.821886
# std         4.397621
# min         0.100000
# 25%         1.600000
# 50%         3.300000
# 75%         7.100000
# max        27.700000
# Name: thinness_1_19_years, dtype: float64

# %%
sns.boxplot(x=df2['thinness_1_19_years'])
plt.show()

# %%
# thinness_5-9_years - Univariate analysis

# %%
df2.thinness_5_9_years.describe()
# Out:
# count    2938.000000
# mean        4.852144
# std         4.485854
# min         0.100000
# 25%         1.600000
# 50%         3.300000
# 75%         7.200000
# max        28.600000
# Name: thinness_5_9_years, dtype: float64

# %%
sns.boxplot(x=df2['thinness_5_9_years'])
plt.show()

# %%
# Income_composition_of_resources - Univariate analysis

# %%
df2.Income_composition_of_resources.describe()
# Out:
# count    2938.000000
# mean        0.630362
# std         0.205140
# min         0.000000
# 25%         0.504250
# 50%         0.677000
# 75%         0.772000
# max         0.948000
# Name: Income_composition_of_resources, dtype: float64

# %%
sns.boxplot(x=df2['Income_composition_of_resources'])
plt.show()

# %%
# Schooling - Univariate analysis

# %%
df2.Schooling.describe()
# Out:
# count    2938.000000
# mean       12.009837
# std         3.265139
# min         0.000000
# 25%        10.300000
# 50%        12.300000
# 75%        14.100000
# max        20.700000
# Name: Schooling, dtype: float64

# %%
sns.boxplot(x=df2['Schooling'])
plt.show()

# %%
# infant_deaths - Univariate analysis

# %%
df2.infant_deaths.describe()
# Out:
# count    2938.000000
# mean       30.303948
# std       117.926501
# min         0.000000
# 25%         0.000000
# 50%         3.000000
# 75%        22.000000
# max      1800.000000
# Name: infant_deaths, dtype: float64

# %%
sns.boxplot(x=df2['infant_deaths'])
plt.show()

# %%
# Hepatitis_B - Univariate analysis

# %%
df2.Hepatitis_B.describe()
# Out:
# count    2938.000000
# mean       83.022124
# std        22.996984
# min         1.000000
# 25%        82.000000
# 50%        92.000000
# 75%        96.000000
# max        99.000000
# Name: Hepatitis_B, dtype: float64

# %%
sns.boxplot(x=df2['Hepatitis_B'])
plt.show()

# %%
# Measles - Univariate analysis

# %%
df2.Measles.describe()
# Out:
# count      2938.000000
# mean       2419.592240
# std       11467.272489
# min           0.000000
# 25%           0.000000
# 50%          17.000000
# 75%         360.250000
# max      212183.000000
# Name: Measles, dtype: float64

# %%
sns.boxplot(x=df2['Measles'])
plt.show()

# %%
# BMI - Univariate analysis

# %%
df2.BMI.describe()
# Out:
# count    2938.000000
# mean       38.381178
# std        19.935375
# min         1.000000
# 25%        19.400000
# 50%        43.500000
# 75%        56.100000
# max        87.300000
# Name: BMI, dtype: float64

# %%
sns.boxplot(x=df2['BMI'])
plt.show()

# %%
# under_five_deaths - Univariate analysis

# %%
df2.under_five_deaths.describe()
# Out:
# count    2938.000000
# mean       42.035739
# std       160.445548
# min         0.000000
# 25%         0.000000
# 50%         4.000000
# 75%        28.000000
# max      2500.000000
# Name: under_five_deaths, dtype: float64

# %%
sns.boxplot(x=df2['under_five_deaths'])
plt.show()

# %%
# Polio - Univariate analysis

# %%
df2.Polio.describe()
# Out:
# count    2938.000000
# mean       82.617767
# std        23.367166
# min         3.000000
# 25%        78.000000
# 50%        93.000000
# 75%        97.000000
# max        99.000000
# Name: Polio, dtype: float64

# %%
sns.boxplot(x=df2['Polio'])
plt.show()

# %%
# Diphtheria - Univariate analysis

# %%
df2.Diphtheria.describe()
# Out:
# count    2938.000000
# mean       82.393125
# std        23.655562
# min         2.000000
# 25%        78.000000
# 50%        93.000000
# 75%        97.000000
# max        99.000000
# Name: Diphtheria, dtype: float64

# %%
sns.boxplot(x=df2['Diphtheria'])
plt.show()

# %%
# HIV_AIDS - Univariate analysis

# %%
df2.HIV_AIDS.describe()
# Out:
# count    2938.000000
# mean        1.742103
# std         5.077785
# min         0.100000
# 25%         0.100000
# 50%         0.100000
# 75%         0.800000
# max        50.600000
# Name: HIV_AIDS, dtype: float64

# %%
sns.boxplot(x=df2['HIV_AIDS'])
plt.show()

# %%
df2.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life_expectancy', 'Adult_Mortality',
#        'Alcohol', 'Total_expenditure', 'GDP', 'Population',
#        'thinness_1_19_years', 'thinness_5_9_years',
#        'Income_composition_of_resources', 'Schooling', 'infant_deaths',
#        'Hepatitis_B', 'Measles', 'BMI', 'under_five_deaths', 'Polio',
#        'Diphtheria', 'HIV_AIDS'],
#       dtype='object')

# %%
# 2. BIVARIATE ANALYSIS

# %%
df_Life=df2.drop(['Year'], axis=1)

df_Life['Underweight']=np.where(df_Life['BMI']<18.5, 1, 0)
df_Life['Overweight']=np.where(df_Life['BMI']>24.9, 1, 0)
df_Life['Healthy']=np.where((df_Life['BMI']<24.9)& (df_Life['BMI']>18.5), 1, 0)
df_Life

# def weight(df):

#     if pd.isnull(df['height']):
#         return df['height']
#     elif (df['trigger1'] <= df['score'] < df['trigger2']) and (df['height'] < 8):
#         return df['height']*2
#     elif (df['trigger2'] <= df['score'] < df['trigger3']) and (df['height'] < 8):
#         return df['height']*3
#     elif (df['trigger3'] <= df['score']) and (df['height'] < 8):
#         return df['height']*4
#     elif (df['height'] > 8):
#         return np.nan
# Out:
#           Country      Status  Life_expectancy  Adult_Mortality  Alcohol  \
# 0     Afghanistan  Developing             65.0            263.0     0.01
# 1     Afghanistan  Developing             59.9            271.0     0.01
# 2     Afghanistan  Developing             59.9            268.0     0.01
# 3     Afghanistan  Developing             59.5            272.0     0.01
# 4     Afghanistan  Developing             59.2            275.0     0.01
# ...           ...         ...              ...              ...      ...
# 2933     Zimbabwe  Developing             44.3            723.0     4.36
# 2934     Zimbabwe  Developing             44.5            715.0     4.06
# 2935     Zimbabwe  Developing             44.8             73.0     4.43
# 2936     Zimbabwe  Developing             45.3            686.0     1.72
# 2937     Zimbabwe  Developing             46.0            665.0     1.68
#
#       Total_expenditure         GDP  Population  thinness_1_19_years  \
# 0                  8.16  584.259210  33736494.0                 17.2
# 1                  8.18  612.696514    327582.0                 17.5
# 2                  8.13  631.744976  31731688.0                 17.7
# 3                  8.52  669.959000   3696958.0                 17.9
# 4                  7.87   63.537231   2978599.0                 18.2
# ...                 ...         ...         ...                  ...
# 2933               7.13  454.366654  12777511.0                  9.4
# 2934               6.52  453.351155  12633897.0                  9.8
# 2935               6.53   57.348340    125525.0                  1.2
# 2936               6.16  548.587312  12366165.0                  1.6
# 2937               7.10  547.358878  12222251.0                 11.0
#
#       thinness_5_9_years  ...  Hepatitis_B  Measles   BMI  under_five_deaths  \
# 0                   17.3  ...         65.0     1154  19.1                 83
# 1                   17.5  ...         62.0      492  18.6                 86
# 2                   17.7  ...         64.0      430  18.1                 89
# 3                   18.0  ...         67.0     2787  17.6                 93
# 4                   18.2  ...         68.0     3013  17.2                 97
# ...                  ...  ...          ...      ...   ...                ...
# 2933                 9.4  ...         68.0       31  27.1                 42
# 2934                 9.9  ...          7.0      998  26.7                 41
# 2935                 1.3  ...         73.0      304  26.3                 40
# 2936                 1.7  ...         76.0      529  25.9                 39
# 2937                11.2  ...         79.0     1483  25.5                 39
#
#       Polio  Diphtheria  HIV_AIDS  Underweight  Overweight  Healthy
# 0       6.0        65.0       0.1            0           0        1
# 1      58.0        62.0       0.1            0           0        1
# 2      62.0        64.0       0.1            1           0        0
# 3      67.0        67.0       0.1            1           0        0
# 4      68.0        68.0       0.1            1           0        0
# ...     ...         ...       ...          ...         ...      ...
# 2933   67.0        65.0      33.6            0           1        0
# 2934    7.0        68.0      36.7            0           1        0
# 2935   73.0        71.0      39.8            0           1        0
# 2936   76.0        75.0      42.1            0           1        0
# 2937   78.0        78.0      43.5            0           1        0
#
# [2938 rows x 23 columns]

# %%
# a. a.	Find the highly correlated variables.
corr=df_Life.corr()[['Life_expectancy']].sort_values(by=['Life_expectancy'], ascending=False).reset_index()
corr
# Out:
#                               index  Life_expectancy
# 0                   Life_expectancy         1.000000
# 1                         Schooling         0.713054
# 2   Income_composition_of_resources         0.688662
# 3                               BMI         0.556901
# 4                        Overweight         0.503140
# 5                        Diphtheria         0.472211
# 6                             Polio         0.458399
# 7                               GDP         0.430461
# 8                           Alcohol         0.388918
# 9                 Total_expenditure         0.208844
# 10                      Hepatitis_B         0.170219
# 11                       Population        -0.029014
# 12                          Measles        -0.157767
# 13                    infant_deaths        -0.196769
# 14                under_five_deaths        -0.222738
# 15                      Underweight        -0.320764
# 16                          Healthy        -0.324276
# 17               thinness_5_9_years        -0.462473
# 18              thinness_1_19_years        -0.468002
# 19                         HIV_AIDS        -0.556703
# 20                  Adult_Mortality        -0.696390

# %%
# b.i. developed vs developing countries - GDP per capita of the country impact life expectancy

# %%
sns.scatterplot(x= df2['GDP'], y= df2['Life_expectancy'] , hue= df2['Status'])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('GDP', fontsize=14, fontweight='bold')
plt.show()

o=df2.groupby(['Status'])['GDP','Life_expectancy'].mean().reset_index()
o.rename(columns={'Life_expectancy':'Avg_Life_expectancy','GDP':'Avg_GDP'},inplace=True)
o
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2500\162095409.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   o=df2.groupby(['Status'])['GDP','Life_expectancy'].mean().reset_index()
#        Status       Avg_GDP  Avg_Life_expectancy
# 0   Developed  19517.581590            79.197852
# 1  Developing   3887.739215            67.132028

# %% [markdown]
# # insight:-
# After GDP range above 20000, the life expectancy is not below 70 years

# %%
# b.ii. developed vs developing countries - Income_composition_of_resources impact life expectancy

# %%
sns.scatterplot(x= df2['Income_composition_of_resources'], y= df2['Life_expectancy'] , hue= df2['Status'])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('Income_composition_of_resources', fontsize=14, fontweight='bold')
plt.show()

o=df2.groupby(['Status'])['Income_composition_of_resources','Life_expectancy'].mean().reset_index()
o.rename(columns={'Life_expectancy':'Avg_Life_expectancy','Income_composition_of_resources':'Income_composition_of_resources'},inplace=True)
o
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2500\1880008814.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   o=df2.groupby(['Status'])['Income_composition_of_resources','Life_expectancy'].mean().reset_index()
#        Status  Income_composition_of_resources  Avg_Life_expectancy
# 0   Developed                         0.836037            79.197852
# 1  Developing                         0.586955            67.132028

# %% [markdown]
# #### insight
# Life expectancy is proportional to Income_composition_of_resource

# %%
# b.iii. developed vs developing countries - Schooling impact life expectancy

# %%
sns.jointplot(x= df2['Schooling'], y= df2['Life_expectancy'] , hue= df2['Status'], kind = 'scatter')
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('Schooling', fontsize=14, fontweight='bold')
plt.show()

sns.lineplot(x= df2['Schooling'], y= df2['Life_expectancy'] , hue= df2['Status'])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('Schooling', fontsize=14, fontweight='bold')
plt.show()

o=df2.groupby(['Status'])['Schooling','Life_expectancy'].mean().reset_index()
o.rename(columns={'Life_expectancy':'Avg_Life_expectancy','Schooling':'Avg_Schooling'},inplace=True)
o
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2500\2914156291.py:11: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   o=df2.groupby(['Status'])['Schooling','Life_expectancy'].mean().reset_index()
#        Status  Avg_Schooling  Avg_Life_expectancy
# 0   Developed      15.513086            79.197852
# 1  Developing      11.270486            67.132028

# %%
# under_5 deaths vs schooling
sns.jointplot(x= df2['Schooling'], y= df2['under_five_deaths'] , hue= df2['Status'], kind = 'scatter')
plt.ylabel('under_five_deaths', fontsize= 14, fontweight='bold')
plt.xlabel('under_five_deaths', fontsize=14, fontweight='bold')
plt.show()
o=df2.groupby(['Status'])['Schooling','under_five_deaths'].mean().reset_index()
o.rename(columns={'Life_expectancy':'Avg_Life_expectancy','under_five_deaths':'Avg_under_five_deaths'},inplace=True)
o
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2500\1399323499.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   o=df2.groupby(['Status'])['Schooling','under_five_deaths'].mean().reset_index()
#        Status  Schooling  Avg_under_five_deaths
# 0   Developed  15.513086               1.810547
# 1  Developing  11.270486              50.525144

# %%
# thinness_1_19_years vs schooling
sns.jointplot(x= df2['Schooling'], y= df2['thinness_1_19_years'] , hue= df2['Status'], kind = 'scatter')
plt.ylabel('thinness_1_19_years', fontsize= 14, fontweight='bold')
plt.xlabel('thinness_1_19_years', fontsize=14, fontweight='bold')
plt.show()
o=df2.groupby(['Status'])['Schooling','thinness_1_19_years'].mean().reset_index()
o.rename(columns={'Life_expectancy':'Avg_Life_expectancy','thinness_1_19_years':'Avg_thinness_1_19_years'},inplace=True)
o
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2500\149255844.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   o=df2.groupby(['Status'])['Schooling','thinness_1_19_years'].mean().reset_index()
#        Status  Schooling  Avg_thinness_1_19_years
# 0   Developed  15.513086                 1.320703
# 1  Developing  11.270486                 5.560800

# %%
# thinness_5_9_years vs schooling
sns.jointplot(x= df2['Schooling'], y= df2['thinness_5_9_years'] , hue= df2['Status'], kind = 'scatter')
plt.ylabel('thinness_5_9_years', fontsize= 14, fontweight='bold')
plt.xlabel('thinness_5_9_years', fontsize=14, fontweight='bold')
plt.show()
o=df2.groupby(['Status'])['Schooling','thinness_5_9_years'].mean().reset_index()
o.rename(columns={'Life_expectancy':'Avg_Life_expectancy','thinness_1_19_years':'Avg_thinness_5_9_years'},inplace=True)
o
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2500\1898165547.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   o=df2.groupby(['Status'])['Schooling','thinness_5_9_years'].mean().reset_index()
#        Status  Schooling  thinness_5_9_years
# 0   Developed  15.513086            1.296680
# 1  Developing  11.270486            5.602514

# %% [markdown]
# ## insight
#
# > The shooling does increases life expectancy.
# In developing countries - Life expectancy s constantly increasing from schooling avg schooling i.e. 11 to 16(approximately).
#
# >IN developed countries minimum schooling is above 10 and upto 20 and life expectancy increases with schooling
#
# > Schooling reduces under five deaths , the rate of under five death is more in developing countries
# > Schooling reduces thinness in both 1-19 & 5-9 groups

# %% [markdown]
# # 3. Multivariate analysis

# %%
# a. Which diseases are correlated with life expectancy?

# %%
ad=df2[['Status','Life_expectancy','thinness_1_19_years', 'thinness_5_9_years', 'infant_deaths',
       'Hepatitis_B', 'Measles', 'under_five_deaths', 'Polio',
       'Diphtheria', 'HIV_AIDS']]
ad
# Out:
#           Status  Life_expectancy  thinness_1_19_years  thinness_5_9_years  \
# 0     Developing             65.0                 17.2                17.3
# 1     Developing             59.9                 17.5                17.5
# 2     Developing             59.9                 17.7                17.7
# 3     Developing             59.5                 17.9                18.0
# 4     Developing             59.2                 18.2                18.2
# ...          ...              ...                  ...                 ...
# 2933  Developing             44.3                  9.4                 9.4
# 2934  Developing             44.5                  9.8                 9.9
# 2935  Developing             44.8                  1.2                 1.3
# 2936  Developing             45.3                  1.6                 1.7
# 2937  Developing             46.0                 11.0                11.2
#
#       infant_deaths  Hepatitis_B  Measles  under_five_deaths  Polio  \
# 0                62         65.0     1154                 83    6.0
# 1                64         62.0      492                 86   58.0
# 2                66         64.0      430                 89   62.0
# 3                69         67.0     2787                 93   67.0
# 4                71         68.0     3013                 97   68.0
# ...             ...          ...      ...                ...    ...
# 2933             27         68.0       31                 42   67.0
# 2934             26          7.0      998                 41    7.0
# 2935             25         73.0      304                 40   73.0
# 2936             25         76.0      529                 39   76.0
# 2937             24         79.0     1483                 39   78.0
#
#       Diphtheria  HIV_AIDS
# 0           65.0       0.1
# 1           62.0       0.1
# 2           64.0       0.1
# 3           67.0       0.1
# 4           68.0       0.1
# ...          ...       ...
# 2933        65.0      33.6
# 2934        68.0      36.7
# 2935        71.0      39.8
# 2936        75.0      42.1
# 2937        78.0      43.5
#
# [2938 rows x 11 columns]

# %%
ad.columns
# Out:
# Index(['Status', 'Life_expectancy', 'thinness_1_19_years',
#        'thinness_5_9_years', 'infant_deaths', 'Hepatitis_B', 'Measles',
#        'under_five_deaths', 'Polio', 'Diphtheria', 'HIV_AIDS'],
#       dtype='object')

# %%
# aab=ad.plot(x='Life_expectancy', y=['thinness_1_19_years',
#        'thinness_5_9_years', 'infant_deaths', 'Hepatitis_B', 'Measles',
#        'under_five_deaths', 'Polio', 'Diphtheria', 'HIV_AIDS'],kind='bar')

# %%
ad=df2[['Status','Life_expectancy','thinness_1_19_years', 'thinness_5_9_years', 'infant_deaths',
       'Hepatitis_B', 'Measles', 'under_five_deaths', 'Polio',
       'Diphtheria', 'HIV_AIDS']]
ad

cor=ad.corr()[['Life_expectancy']].sort_values(by=['Life_expectancy'], ascending=True).reset_index()
cor.rename(columns={'index':'Name'},inplace=True)
cor
# Out:
#                   Name  Life_expectancy
# 0             HIV_AIDS        -0.556703
# 1  thinness_1_19_years        -0.468002
# 2   thinness_5_9_years        -0.462473
# 3    under_five_deaths        -0.222738
# 4        infant_deaths        -0.196769
# 5              Measles        -0.157767
# 6          Hepatitis_B         0.170219
# 7                Polio         0.458399
# 8           Diphtheria         0.472211
# 9      Life_expectancy         1.000000

# %%
af=cor.Name.values.tolist()
af.pop()
print('Diseases affecting the life expectancy are as below:- ')
for i in af:
    print(af.index(i)+1,' - ',i)
# Out:
# Diseases affecting the life expectancy are as below:-
# 1  -  HIV_AIDS
# 2  -  thinness_1_19_years
# 3  -  thinness_5_9_years
# 4  -  under_five_deaths
# 5  -  infant_deaths
# 6  -  Measles
# 7  -  Hepatitis_B
# 8  -  Polio
# 9  -  Diphtheria

# %%
# b. Does better immunization coverage improve life expectancy

# %%
an=df2[['Status','Life_expectancy','GDP', 'Total_expenditure']]
an

cor=an.corr()[['Life_expectancy']].sort_values(by=['Life_expectancy'], ascending=True).reset_index()
cor.rename(columns={'index':'Name'},inplace=True)
cor
# Out:
#                 Name  Life_expectancy
# 0  Total_expenditure         0.208844
# 1                GDP         0.430461
# 2    Life_expectancy         1.000000

# %%
sns.jointplot(x= an['Total_expenditure'], y= an['Life_expectancy'] , hue= an['Status'], kind = 'scatter')
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('Total_expenditure', fontsize=14, fontweight='bold')
plt.show()

cor=an.corr()[['Life_expectancy']].sort_values(by=['Life_expectancy'], ascending=True).reset_index()
cor.rename(columns={'index':'Name'},inplace=True)
cor
# Out:
#                 Name  Life_expectancy
# 0  Total_expenditure         0.208844
# 1                GDP         0.430461
# 2    Life_expectancy         1.000000

# %% [markdown]
# ### Insights:
# > The Income composition is directly proportional to life expectancy, but it is not afeecting in big way
#
# > For low GDP countries, they will have to increase Total_expenditure

# %%
# C. How do countries' economic conditions affect life expectancy

# %%
sns.pairplot(df2[[ 'Status', 'Life_expectancy', 'Total_expenditure', 'GDP',]],hue='Status')
plt.show()

# %%
sns.scatterplot(x= df2['GDP'], y= df2['Life_expectancy'] , hue= df2['Status'])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('GDP', fontsize=14, fontweight='bold')
plt.show()

o=df2.groupby(['Status'])['GDP','Life_expectancy'].mean().reset_index()
o.rename(columns={'Life_expectancy':'Avg_Life_expectancy','GDP':'Avg_GDP'},inplace=True)
o
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2500\162095409.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   o=df2.groupby(['Status'])['GDP','Life_expectancy'].mean().reset_index()
#        Status       Avg_GDP  Avg_Life_expectancy
# 0   Developed  19517.581590            79.197852
# 1  Developing   3887.739215            67.132028

# %% [markdown]
# # insight
#
# > if GDP increases the life expectancy also increases
#
# > in countries who have GDP above 15000 life expectancy is expected to be above 70

# %% [markdown]
# # Task 02

# %% [markdown]
# ## a. Calculate the average life expectancy of all the years and find out Top and Bottom countries.

# %%
# top 10 countries with high life expectancy
print("Top 10 Countries with high Life Expectancy")
df2.groupby("Country").agg({"Life_expectancy":"mean"
}).reset_index().sort_values(by=["Life_expectancy"], ascending = False).head(10)
# Out:
# Top 10 Countries with high Life Expectancy
#          Country  Life_expectancy
# 84         Japan         82.53750
# 165       Sweden         82.51875
# 75       Iceland         82.44375
# 166  Switzerland         82.33125
# 60        France         82.21875
# 82         Italy         82.18750
# 160        Spain         82.06875
# 7      Australia         81.81250
# 125       Norway         81.79375
# 30        Canada         81.68750

# %%
# top 10 countries with low life expectancy
print("Top 10 Countries with low Life Expectancy")
df2.groupby("Country").agg({"Life_expectancy":"mean"
}).reset_index().sort_values(by=["Life_expectancy"], ascending = True).head(10)
# Out:
# Top 10 Countries with low Life Expectancy
#                       Country  Life_expectancy
# 152              Sierra Leone         46.11250
# 31   Central African Republic         48.51250
# 94                    Lesotho         48.78125
# 3                      Angola         49.01875
# 100                    Malawi         49.89375
# 32                       Chad         50.38750
# 44              Côte d'Ivoire         50.38750
# 192                  Zimbabwe         50.48750
# 164                 Swaziland         51.32500
# 123                   Nigeria         51.35625

# %% [markdown]
# ### Insights:-
# > country with highest life expectancy = Japan
#
# > country with highest life expectancy = Sierra Leone

# %% [markdown]
# ## b.	Rank countries based on their average life expectancy.

# %%
a=df2.groupby(['Country'])['Life_expectancy'].mean().reset_index().sort_values(by=['Life_expectancy'],
                                                                              ascending=False)
a['Rank']=a['Life_expectancy'].rank(ascending=False).astype(int)
a
# Out:
#                       Country  Life_expectancy  Rank
# 84                      Japan         82.53750     1
# 165                    Sweden         82.51875     2
# 75                    Iceland         82.44375     3
# 166               Switzerland         82.33125     4
# 60                     France         82.21875     5
# ..                        ...              ...   ...
# 100                    Malawi         49.89375   189
# 3                      Angola         49.01875   190
# 94                    Lesotho         48.78125   191
# 31   Central African Republic         48.51250   192
# 152              Sierra Leone         46.11250   193
#
# [193 rows x 3 columns]

# %% [markdown]
# # c. Compare a few country’s life expectancies.
# India, the United States of America, China, the Central African Republic, Bhutan

# %%
a=df2.Country.unique().tolist() # to check country name

# %%
df_Country=df2[df2['Country'].isin(['India', 'United States of America', 'China', 'Central African Republic','Bhutan'])]
df_Country
# Out:
#                        Country  Year      Status  Life_expectancy  \
# 288                     Bhutan  2015  Developing             69.8
# 289                     Bhutan  2014  Developing             69.4
# 290                     Bhutan  2013  Developing             69.1
# 291                     Bhutan  2012  Developing             68.7
# 292                     Bhutan  2011  Developing             68.3
# ...                        ...   ...         ...              ...
# 2805  United States of America  2004   Developed             77.5
# 2806  United States of America  2003   Developed             77.2
# 2807  United States of America  2002   Developed             77.0
# 2808  United States of America  2001   Developed             76.9
# 2809  United States of America  2000   Developed             76.8
#
#       Adult_Mortality  Alcohol  Total_expenditure          GDP  Population  \
# 288             211.0    3.755              5.755  2613.645177    787386.0
# 289             216.0    0.010              3.570  2522.796800    776448.0
# 290             219.0    0.010              3.830   235.882889    764961.0
# 291             223.0    0.010              3.700  2422.816000    752967.0
# 292             225.0    0.230              4.730  2458.459760      7451.0
# ...               ...      ...                ...          ...         ...
# 2805            111.0    8.480             15.140  1766.947595   1386542.0
# 2806            114.0    8.400             15.600  1766.947595   1386542.0
# 2807            115.0    8.330             14.550  1766.947595   1386542.0
# 2808            115.0    8.250             13.730  1766.947595   1386542.0
# 2809            114.0    8.210             13.700  1766.947595   1386542.0
#
#       thinness_1_19_years  ...  Income_composition_of_resources  Schooling  \
# 288                  15.4  ...                            0.604       12.5
# 289                  15.7  ...                            0.596       12.5
# 290                  15.9  ...                            0.589       12.6
# 291                  16.1  ...                            0.581       12.3
# 292                  16.3  ...                            0.572       11.9
# ...                   ...  ...                              ...        ...
# 2805                  0.7  ...                            0.677       12.3
# 2806                  0.7  ...                            0.677       12.3
# 2807                  0.8  ...                            0.677       12.3
# 2808                  0.8  ...                            0.677       12.3
# 2809                  0.8  ...                            0.677       12.3
#
#       infant_deaths  Hepatitis_B  Measles   BMI  under_five_deaths  Polio  \
# 288               0         99.0       11  24.5                  0   98.0
# 289               0         99.0        0  23.6                  1   98.0
# 290               0         97.0        0  22.7                  1   97.0
# 291               0         97.0        1  21.9                  1   97.0
# 292               0         95.0       10  21.1                  1   95.0
# ...             ...          ...      ...   ...                ...    ...
# 2805             28         92.0       37  63.1                 33   92.0
# 2806             28         92.0       56  62.4                 33   91.0
# 2807             28         88.0       41  61.7                 33    9.0
# 2808             28         89.0      116   6.9                 33   89.0
# 2809             28          9.0       85   6.1                 33    9.0
#
#       Diphtheria  HIV_AIDS
# 288         99.0       0.5
# 289         99.0       0.5
# 290         97.0       0.6
# 291         97.0       0.6
# 292         95.0       0.5
# ...          ...       ...
# 2805        96.0       0.1
# 2806        96.0       0.1
# 2807        94.0       0.1
# 2808        94.0       0.1
# 2809        94.0       0.1
#
# [80 rows x 21 columns]

# %%
CO=df_Country.groupby(['Status'])['Life_expectancy'].mean().reset_index()
CO
# Out:
#        Status  Life_expectancy
# 0   Developed        78.062500
# 1  Developing        63.589062

# %%
CO=df_Country.groupby(['Country','Status'])['Life_expectancy'].mean().reset_index()
CO
# Out:
#                     Country      Status  Life_expectancy
# 0                    Bhutan  Developing         66.16250
# 1  Central African Republic  Developing         48.51250
# 2                     China  Developing         74.26250
# 3                     India  Developing         65.41875
# 4  United States of America   Developed         78.06250

# %%
sns.barplot(x= CO['Country'], y= CO['Life_expectancy'] , hue= CO['Status'])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('Country', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# # d. Compare life expectancy of Developed vs Developing country.

# %%
Dev=df2.groupby(['Status'])['Life_expectancy'].mean().reset_index()
Dev
# Out:
#        Status  Life_expectancy
# 0   Developed        79.197852
# 1  Developing        67.132028

# %%
a=sns.barplot(x= Dev['Status'], y= Dev['Life_expectancy'])
l=a.bar_label(a.containers[0])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('Status', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# # 2. Let’s take few developing and developed countries and analyze them completely.

# %%
df_Country=df2[df2['Country'].isin(['India', 'United States of America', 'China', 'Central African Republic','Bhutan'])]
df_Country
# Out:
#                        Country  Year      Status  Life_expectancy  \
# 288                     Bhutan  2015  Developing             69.8
# 289                     Bhutan  2014  Developing             69.4
# 290                     Bhutan  2013  Developing             69.1
# 291                     Bhutan  2012  Developing             68.7
# 292                     Bhutan  2011  Developing             68.3
# ...                        ...   ...         ...              ...
# 2805  United States of America  2004   Developed             77.5
# 2806  United States of America  2003   Developed             77.2
# 2807  United States of America  2002   Developed             77.0
# 2808  United States of America  2001   Developed             76.9
# 2809  United States of America  2000   Developed             76.8
#
#       Adult_Mortality  Alcohol  Total_expenditure          GDP  Population  \
# 288             211.0    3.755              5.755  2613.645177    787386.0
# 289             216.0    0.010              3.570  2522.796800    776448.0
# 290             219.0    0.010              3.830   235.882889    764961.0
# 291             223.0    0.010              3.700  2422.816000    752967.0
# 292             225.0    0.230              4.730  2458.459760      7451.0
# ...               ...      ...                ...          ...         ...
# 2805            111.0    8.480             15.140  1766.947595   1386542.0
# 2806            114.0    8.400             15.600  1766.947595   1386542.0
# 2807            115.0    8.330             14.550  1766.947595   1386542.0
# 2808            115.0    8.250             13.730  1766.947595   1386542.0
# 2809            114.0    8.210             13.700  1766.947595   1386542.0
#
#       thinness_1_19_years  ...  Income_composition_of_resources  Schooling  \
# 288                  15.4  ...                            0.604       12.5
# 289                  15.7  ...                            0.596       12.5
# 290                  15.9  ...                            0.589       12.6
# 291                  16.1  ...                            0.581       12.3
# 292                  16.3  ...                            0.572       11.9
# ...                   ...  ...                              ...        ...
# 2805                  0.7  ...                            0.677       12.3
# 2806                  0.7  ...                            0.677       12.3
# 2807                  0.8  ...                            0.677       12.3
# 2808                  0.8  ...                            0.677       12.3
# 2809                  0.8  ...                            0.677       12.3
#
#       infant_deaths  Hepatitis_B  Measles   BMI  under_five_deaths  Polio  \
# 288               0         99.0       11  24.5                  0   98.0
# 289               0         99.0        0  23.6                  1   98.0
# 290               0         97.0        0  22.7                  1   97.0
# 291               0         97.0        1  21.9                  1   97.0
# 292               0         95.0       10  21.1                  1   95.0
# ...             ...          ...      ...   ...                ...    ...
# 2805             28         92.0       37  63.1                 33   92.0
# 2806             28         92.0       56  62.4                 33   91.0
# 2807             28         88.0       41  61.7                 33    9.0
# 2808             28         89.0      116   6.9                 33   89.0
# 2809             28          9.0       85   6.1                 33    9.0
#
#       Diphtheria  HIV_AIDS
# 288         99.0       0.5
# 289         99.0       0.5
# 290         97.0       0.6
# 291         97.0       0.6
# 292         95.0       0.5
# ...          ...       ...
# 2805        96.0       0.1
# 2806        96.0       0.1
# 2807        94.0       0.1
# 2808        94.0       0.1
# 2809        94.0       0.1
#
# [80 rows x 21 columns]

# %%
cor=df_Country.corr()[['Life_expectancy']].sort_values(by=['Life_expectancy'], ascending=True).reset_index()
cor.rename(columns={'index':'Name'},inplace=True)
cor
# Out:
#                                Name  Life_expectancy
# 0                          HIV_AIDS        -0.846287
# 1                   Adult_Mortality        -0.633661
# 2                thinness_5_9_years        -0.235667
# 3               thinness_1_19_years        -0.232483
# 4                        Population        -0.031698
# 5                 under_five_deaths        -0.005875
# 6                     infant_deaths         0.006495
# 7                       Hepatitis_B         0.119290
# 8                              Year         0.179671
# 9                           Measles         0.248175
# 10                              GDP         0.501067
# 11                              BMI         0.538300
# 12                Total_expenditure         0.576995
# 13  Income_composition_of_resources         0.586591
# 14                          Alcohol         0.668947
# 15                            Polio         0.675284
# 16                       Diphtheria         0.826177
# 17                        Schooling         0.932544
# 18                  Life_expectancy         1.000000

# %%
# 3. Let’s look more
# a. Should a country having a lower life expectancy value(<65) increase its healthcare expenditure to improve its average lifespan?

# %%
df_life=df_Country.groupby(['Country'])['Life_expectancy','Total_expenditure','BMI','Alcohol','Population'].mean().reset_index()
df_life
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2500\3815524282.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_life=df_Country.groupby(['Country'])['Life_expectancy','Total_expenditure','BMI','Alcohol','Population'].mean().reset_index()
#                     Country  Life_expectancy  Total_expenditure       BMI  \
# 0                    Bhutan         66.16250           5.371563  17.58125
# 1  Central African Republic         48.51250           4.146562  17.08750
# 2                     China         74.26250           4.970312  21.80625
# 3                     India         65.41875           4.445938  14.79375
# 4  United States of America         78.06250          15.231562  58.45000
#
#     Alcohol    Population
# 0  0.495937  4.925849e+05
# 1  1.389063  2.016546e+06
# 2  4.155312  3.218121e+05
# 3  2.055312  4.214677e+08
# 4  8.277812  1.386542e+06

# %%
df_life.sort_values(by=['Total_expenditure'], ascending=True,inplace=True)
df_life
# Out:
#                     Country  Life_expectancy  Total_expenditure       BMI  \
# 1  Central African Republic         48.51250           4.146562  17.08750
# 3                     India         65.41875           4.445938  14.79375
# 2                     China         74.26250           4.970312  21.80625
# 0                    Bhutan         66.16250           5.371563  17.58125
# 4  United States of America         78.06250          15.231562  58.45000
#
#     Alcohol    Population
# 1  1.389063  2.016546e+06
# 3  2.055312  4.214677e+08
# 2  4.155312  3.218121e+05
# 0  0.495937  4.925849e+05
# 4  8.277812  1.386542e+06

# %%
a=sns.barplot(x= df_life['Total_expenditure'], y= df_life['Life_expectancy'])
l=a.bar_label(a.containers[0])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('Total_expenditure', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### INSIGHT:
# > Countries with more higher expenditure has more life expectancy, so countries with life expectancy <65 should increase their Total expenditure

# %%
# b. Does Life Expectancy have a positive or negative correlation with eating habits(BMI), lifestyle, exercise, smoking, drinking alcohol, etc?

# %%
# correlation between data
cor=df_life.corr()[['Life_expectancy']].sort_values(by=['Life_expectancy'], 
                                                    ascending=True).reset_index()
cor
# Out:
#                index  Life_expectancy
# 0         Population        -0.054491
# 1                BMI         0.619685
# 2  Total_expenditure         0.623634
# 3            Alcohol         0.713004
# 4    Life_expectancy         1.000000

# %%
# BMI VS LIFE EXPECTANCY

# %%
a=sns.barplot(x= df_life['BMI'], y= df_life['Life_expectancy'])
l=a.bar_label(a.containers[0])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('BMI', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
f=df2.groupby(['Country'])['BMI','Life_expectancy','Alcohol'].mean().reset_index()
f
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2500\349969300.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   f=df2.groupby(['Country'])['BMI','Life_expectancy','Alcohol'].mean().reset_index()
#                                 Country       BMI  Life_expectancy   Alcohol
# 0                           Afghanistan  15.51875         58.19375  0.014375
# 1                               Albania  49.06875         75.15625  4.848750
# 2                               Algeria  48.74375         73.61875  0.615938
# 3                                Angola  18.01875         49.01875  5.616562
# 4                   Antigua and Barbuda  38.42500         75.05625  7.687188
# ..                                  ...       ...              ...       ...
# 188  Venezuela (Bolivarian Republic of)  54.48750         73.38750  7.190937
# 189                            Viet Nam  11.18750         74.77500  3.129062
# 190                               Yemen  33.48750         63.86250  0.279062
# 191                              Zambia  17.45000         53.90625  2.334062
# 192                            Zimbabwe  25.13750         50.48750  4.436562
#
# [193 rows x 4 columns]

# %%
# low BMI VS life expectancy
f.sort_values(by=['BMI'], ascending=True).reset_index()
l=f.head(10)
l
# Out:
#                Country       BMI  Life_expectancy    Alcohol
# 0          Afghanistan  15.51875         58.19375   0.014375
# 1              Albania  49.06875         75.15625   4.848750
# 2              Algeria  48.74375         73.61875   0.615938
# 3               Angola  18.01875         49.01875   5.616562
# 4  Antigua and Barbuda  38.42500         75.05625   7.687188
# 5            Argentina  54.98125         75.15625   7.703437
# 6              Armenia  44.70625         73.40000   3.705938
# 7            Australia  55.86250         81.81250   9.755313
# 8              Austria  48.28750         81.48125  11.705937
# 9           Azerbaijan  43.84375         70.73125   1.164687

# %%
a=sns.barplot(x=l['Life_expectancy'], y= l['BMI'])
l=a.bar_label(a.containers[0])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('BMI', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
# High BMI VS life expectancy
m=f.sort_values(by=['BMI'], ascending=False).reset_index().head(10)
m
# Out:
#    index                           Country       BMI  Life_expectancy  \
# 0    117                             Nauru  87.30000         72.10000
# 1    128                             Palau  83.30000         72.10000
# 2     38                      Cook Islands  82.80000         72.10000
# 3    105                  Marshall Islands  81.60000         72.10000
# 4    178                            Tuvalu  79.30000         72.10000
# 5    124                              Niue  77.30000         72.10000
# 6     88                          Kiribati  69.43125         65.15000
# 7    104                             Malta  66.18125         80.36250
# 8    136                             Qatar  65.65000         77.03125
# 9    109  Micronesia (Federated States of)  65.15000         68.20000
#
#     Alcohol
# 0  0.010000
# 1  3.755000
# 2  0.010000
# 3  0.010000
# 4  0.010000
# 5  0.010000
# 6  0.647813
# 7  6.919062
# 8  1.248438
# 9  2.245938

# %%
b=sns.barplot(x=m.Life_expectancy, y= m.BMI)
l=b.bar_label(b.containers[0])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('BMI', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
# Alcohol vs life expectancy

# %%
# Low alcohol vs life expectancy
f.sort_values(by=['Alcohol'], ascending=True).reset_index()
l=f.head(10)
l
# Out:
#                Country       BMI  Life_expectancy    Alcohol
# 0          Afghanistan  15.51875         58.19375   0.014375
# 1              Albania  49.06875         75.15625   4.848750
# 2              Algeria  48.74375         73.61875   0.615938
# 3               Angola  18.01875         49.01875   5.616562
# 4  Antigua and Barbuda  38.42500         75.05625   7.687188
# 5            Argentina  54.98125         75.15625   7.703437
# 6              Armenia  44.70625         73.40000   3.705938
# 7            Australia  55.86250         81.81250   9.755313
# 8              Austria  48.28750         81.48125  11.705937
# 9           Azerbaijan  43.84375         70.73125   1.164687

# %%
a=sns.barplot(x=l.Life_expectancy, y=l.Alcohol)
l=a.bar_label(a.containers[0])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('Alcohol', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
# High Alcohol VS life expectancy
m=f.sort_values(by=['Alcohol'], ascending=False).reset_index().head(10)
m
# Out:
#    index     Country       BMI  Life_expectancy    Alcohol
# 0     14     Belarus  54.74375         69.90625  12.888438
# 1     43     Czechia  55.71250         76.76875  12.446563
# 2     80     Ireland  53.68750         80.15000  12.097812
# 3     97   Lithuania  49.23125         72.80625  12.077813
# 4     40     Croatia  52.35625         76.11875  11.904687
# 5     60      France  51.98125         82.21875  11.864062
# 6      8     Austria  48.28750         81.48125  11.705937
# 7    135    Portugal  43.63125         79.99375  11.682813
# 8     98  Luxembourg  47.82500         80.78125  11.411563
# 9     64     Germany  51.99375         81.17500  11.136563

# %%
b=sns.barplot(x=m.Life_expectancy, y= m.Alcohol)
l=b.bar_label(b.containers[0])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('Alcohol', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### INSIGHT:
# > country with low BMI have low life expectancy
#
# > Countries with high BMI has life expectancy above 65
#
# > country with low Alcohol have low life expectancy
#
# > Countries with high Alcohol has life expectancy above 65

# %% [markdown]
# # c. Do densely populated countries tend to have a lower life expectancy?

# %%
df_life.sort_values(by=['Population'], ascending=True,inplace=True)
df_life
# Out:
#                     Country  Life_expectancy  Total_expenditure       BMI  \
# 2                     China         74.26250           4.970312  21.80625
# 0                    Bhutan         66.16250           5.371563  17.58125
# 4  United States of America         78.06250          15.231562  58.45000
# 1  Central African Republic         48.51250           4.146562  17.08750
# 3                     India         65.41875           4.445938  14.79375
#
#     Alcohol    Population
# 2  4.155312  3.218121e+05
# 0  0.495937  4.925849e+05
# 4  8.277812  1.386542e+06
# 1  1.389063  2.016546e+06
# 3  2.055312  4.214677e+08

# %%
b=sns.barplot(x=df_life.Population, y= df_life.Life_expectancy)
l=b.bar_label(b.containers[0])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('Population', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
# low Population VS life expectancy
a=df2.groupby(['Country'])['Population','Life_expectancy'].mean().reset_index()
a
a.sort_values(by=['Population'], ascending=True).reset_index()
l=a.head(10)
l
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2500\1788990246.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   a=df2.groupby(['Country'])['Population','Life_expectancy'].mean().reset_index()
#                Country    Population  Life_expectancy
# 0          Afghanistan  9.972260e+06         58.19375
# 1              Albania  6.969116e+05         75.15625
# 2              Algeria  2.164983e+07         73.61875
# 3               Angola  1.014710e+07         49.01875
# 4  Antigua and Barbuda  1.386542e+06         75.05625
# 5            Argentina  2.012120e+07         75.15625
# 6              Armenia  1.015165e+06         73.40000
# 7            Australia  4.587010e+06         81.81250
# 8              Austria  6.474880e+06         81.48125
# 9           Azerbaijan  2.157370e+06         70.73125

# %%
b=sns.barplot(x=l.Population, y=l.Life_expectancy)
l=b.bar_label(b.containers[0])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('Population', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %%
# High Population VS life expectancy

k=df2.groupby(['Country'])['Population','Life_expectancy'].mean().reset_index()
k
k.sort_values(by=['Population'], ascending=True).reset_index()
t=k.tail(10)
t
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2500\2888176394.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   k=df2.groupby(['Country'])['Population','Life_expectancy'].mean().reset_index()
#                                 Country    Population  Life_expectancy
# 183         United Republic of Tanzania  1.386542e+06         56.00625
# 184            United States of America  1.386542e+06         78.06250
# 185                             Uruguay  2.396771e+06         76.07500
# 186                          Uzbekistan  9.036317e+05         68.03125
# 187                             Vanuatu  1.230962e+05         71.38750
# 188  Venezuela (Bolivarian Republic of)  1.386542e+06         73.38750
# 189                            Viet Nam  1.386542e+06         74.77500
# 190                               Yemen  1.386542e+06         63.86250
# 191                              Zambia  6.260246e+06         53.90625
# 192                            Zimbabwe  8.021343e+06         50.48750

# %%
c=sns.barplot(x=t.Population, y=t.Life_expectancy)
l=c.bar_label(c.containers[0])
plt.ylabel('Life Expectancy', fontsize= 14, fontweight='bold')
plt.xlabel('Population', fontsize=14, fontweight='bold')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### INSIGHTS:
#
# > Population does not have major impact on life expectancy

# %% [markdown]
# # Colnclusion
# 1. predicting variables actually affecting life expectancy

# %%
cor=df2.corr()[['Life_expectancy']].sort_values(by=['Life_expectancy'], ascending=True).reset_index()
cor.rename(columns={'index':'Name','Life_expectancy':'Impact on increasing life expectancy'},inplace=True)
cor
# Out:
#                                Name  Impact on increasing life expectancy
# 0                   Adult_Mortality                             -0.696390
# 1                          HIV_AIDS                             -0.556703
# 2               thinness_1_19_years                             -0.468002
# 3                thinness_5_9_years                             -0.462473
# 4                 under_five_deaths                             -0.222738
# 5                     infant_deaths                             -0.196769
# 6                           Measles                             -0.157767
# 7                        Population                             -0.029014
# 8                       Hepatitis_B                              0.170219
# 9                              Year                              0.170819
# 10                Total_expenditure                              0.208844
# 11                          Alcohol                              0.388918
# 12                              GDP                              0.430461
# 13                            Polio                              0.458399
# 14                       Diphtheria                              0.472211
# 15                              BMI                              0.556901
# 16  Income_composition_of_resources                              0.688662
# 17                        Schooling                              0.713054
# 18                  Life_expectancy                              1.000000

# %% [markdown]
# 2. Should a country having a lower life expectancy value (<65) increase its healthcare expenditure to improve its average lifespan
# > The Income composition is directly proportional to life expectancy, but it is not effecting in big way
#
# > For low GDP countries, they will have to increase Total_expenditure

# %% [markdown]
# 3. How do Infant and Adult mortality rates affect life expectancy?

# %%
j=df2.groupby(['Country'])['Adult_Mortality','infant_deaths', 'Life_expectancy'].mean().reset_index()
j.sort_values(by=['Life_expectancy'], ascending=True, inplace=True)
j.corr()[['Life_expectancy']].sort_values(by=['Life_expectancy'], ascending=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2500\3235102192.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   j=df2.groupby(['Country'])['Adult_Mortality','infant_deaths', 'Life_expectancy'].mean().reset_index()
#                  Life_expectancy
# Adult_Mortality        -0.896588
# infant_deaths          -0.203306
# Life_expectancy         1.000000

# %% [markdown]
# > Adult mortality and infant mortality are inversly proportional to Lifr expectany
#
# > Adult mortality and infant mortality reduces life expectancy. Adult majority is major contributor

# %% [markdown]
# 4.	Does Life Expectancy have a positive or negative correlation with eating habits, lifestyle, exercise, smoking, drinking alcohol, etc?
#
# > country with low BMI have low life expectancy
#
# > Countries with high BMI has life expectancy above 65
#
# > country with low Alcohol have low life expectancy
#
# > Countries with high Alcohol has life expectancy above 65

# %% [markdown]
# 5.	What is the impact of schooling on the lifespan of humans?
#
# >The shooling does increases life expectancy. In developing countries - Life expectancy s constantly increasing from schooling avg schooling i.e. 11 to 16(approximately).
#
# >IN developed countries minimum schooling is above 10 and upto 20 and life expectancy increases with schooling
#
# >Schooling reduces under five deaths , the rate of under five death is more in developing countries Schooling reduces thinness in both 1-19 & 5-9 groups

# %% [markdown]
# 6.	Does Life Expectancy have a positive or negative relationship with drinking alcohol?
#
# > country with low Alcohol have low life expectancy
#
# > Countries with high Alcohol has life expectancy above 65

# %% [markdown]
# 7.	Do densely populated countries tend to have a lower life expectancy?
# > Population does not have major impact on life expectancy

# %% [markdown]
# 8.	What is the impact of Immunization coverage on life Expectancy?
#
# >Countries with more higher expenditure has more life expectancy, so countries with life expectancy <65 should increase their Total expenditure
